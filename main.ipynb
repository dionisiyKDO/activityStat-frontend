# %%
# imports + get_df
import pandas as pd
import numpy as np
import plotly.express as px

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
pd.options.mode.chained_assignment = None
pd.options.display.precision = 8

# render plots in browser 
import plotly.io as pio
pio.renderers.default = 'browser'

from main import *

df_og = get_df()

# %%
# Total spent time on each app
plot_total_spent_time(df_og)

# %%
# App usage over time
daily_app_usage_timeline(df_og, app_name='Risk of Rain 2.exe')
# Out:
# 2984176
#                               timestamp    duration           app  \
# 0      2023-10-18 18:22:34.250000+00:00  0.00281222    chrome.exe
# 1      2023-10-18 18:22:31.217000+00:00  0.00056139  explorer.exe
# 2      2023-10-18 18:22:18.078000+00:00  0.00336833    chrome.exe
# 3      2023-10-18 18:22:05.902000+00:00  0.00310000    chrome.exe
# 4      2023-10-18 18:22:02.847000+00:00  0.00056639    chrome.exe
# ...                                 ...         ...           ...
# 746039 2023-10-18 21:15:18.326000+00:00  0.00112639    chrome.exe
# 746040 2023-10-18 21:15:12.264000+00:00  0.00140278    chrome.exe
# 746041 2023-10-18 21:15:11.238000+00:00  0.00000000     aw-qt.exe
# 746042 2023-10-18 21:15:10.221000+00:00  0.00000000  explorer.exe
# 746043 2023-10-18 21:15:08.191000+00:00  0.00028389  explorer.exe
#
#                                                     title
# 0                           ActivityWatch - Google Chrome
# 1                                     Program Files (x86)
# 2                           ActivityWatch - Google Chrome
# 3       For 12 Hours League of Legends Was On Fire - Y...
# 4                           ActivityWatch - Google Chrome
# ...                                                   ...
# 746039                                               Open
# 746040                      ActivityWatch - Google Chrome
# 746041                                              aw-qt
# 746042
# 746043                                         .Reinstall
#
# [746044 rows x 4 columns]
